# %%
import pandas as pd
csv1_file = "201803_citibikenyc_tripdata.csv"
bikenyc032018_df = pd.read_csv(csv1_file)
bikenyc032018_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           455  2018-03-01 00:00:03  2018-03-01 00:07:39               405
# 1           486  2018-03-01 00:00:06  2018-03-01 00:08:12               146
# 2           333  2018-03-01 00:00:07  2018-03-01 00:05:41               257
# 3          1629  2018-03-01 00:00:21  2018-03-01 00:27:31              3556
# 4            64  2018-03-01 00:00:32  2018-03-01 00:01:37               515
#
#               start station name  start station latitude  \
# 0  Washington St & Gansevoort St               40.739323
# 1           Hudson St & Reade St               40.716250
# 2        Lispenard St & Broadway               40.719392
# 3                 24 St & 41 Ave               40.752709
# 4               W 43 St & 10 Ave               40.760094
#
#    start station longitude  end station id      end station name  \
# 0               -74.008119             368    Carmine St & 6 Ave
# ...

# %%
bikenyc032018_df.shape
# Out:
# (976649, 16)

# %%
#dates_df = bike_df.sort_values(by='starttime')
#dates_df

# %%
#csv2_file = '2013-07 - Citi Bike trip data.csv'
#bike072013_df = pd.read_csv(csv2_file)
#bike072013_df.head()

# %%
#bike072013_df.shape

# %%
csv3_file = '201803_citibikejc_tripdata.csv'
bikejc032018_df = pd.read_csv(csv3_file)
bikejc032018_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0            90  2018-03-01 00:04:48  2018-03-01 00:06:18              3273
# 1           202  2018-03-01 00:15:48  2018-03-01 00:19:10              3185
# 2           237  2018-03-01 00:25:52  2018-03-01 00:29:49              3206
# 3           107  2018-03-01 00:31:51  2018-03-01 00:33:38              3211
# 4           442  2018-03-01 00:42:09  2018-03-01 00:49:32              3205
#
#   start station name  start station latitude  start station longitude  \
# 0       Manila & 1st               40.721651               -74.042884
# 1          City Hall               40.717733               -74.043845
# 2            Hilltop               40.731169               -74.057574
# 3         Newark Ave               40.721525               -74.046305
# 4  JC Medical Center               40.716540               -74.049638
#
#    end station id       end station name  end station latitude  \
# ...

# %%
bikejc032018_df.shape
# Out:
# (17109, 16)

# %%
frames = [bikenyc032018_df, bikejc032018_df]
bike032018_df = pd.concat(frames)

# %%
bike032018_df.shape
# Out:
# (993758, 16)

# %%
bike032018_df.to_csv('201803_citibike_tripdata.csv', index=False)

# %%
#frames = [bike032018_df, bike072013_df]
#citibike_tripdata_df = pd.concat(frames)
#citibike_tripdata_df.to_csv('citibike_tripdata.csv', index=False)

# %%
#citibike_tripdata_df.shape

# %%
#citibike_tripdata_df.head()

# %%
#csv4_file = '2014-03 - Citi Bike trip data.csv'
#bike032014_df = pd.read_csv(csv4_file)
#bike032014_df.head()

# %%
#bike032014_df.shape

# %%
#csv5_file = '201503-citibike-tripdata.csv'
#bike032015_df = pd.read_csv(csv5_file)
#bike032015_df.head()

# %%
#bike032015_df.shape

# %%
#csv6_file = '201603-citibike-tripdata.csv'
#bike032016_df = pd.read_csv(csv6_file)
#bike032016_df.head()

# %%
#bike032016_df.shape

# %%
#csv7_file = '201703-citibike-tripdata.csv'
#bike032017_df = pd.read_csv(csv7_file)
#bike032017_df.head()

# %%
#bike032017_df.shape

# %%
#csv8_file = '201712-citibike-tripdata.csv'
#bike122017_df = pd.read_csv(csv8_file)
#bike122017_df.head()

# %%
#bike122017_df.shape

# %%
csv9_file = '201801_citibikejc_tripdata.csv'
bikejc012018_df = pd.read_csv(csv9_file)
bikejc012018_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           132  2018-01-01 00:01:46  2018-01-01 00:03:58              3186
# 1           560  2018-01-01 01:27:17  2018-01-01 01:36:38              3276
# 2           294  2018-01-01 01:29:03  2018-01-01 01:33:58              3195
# 3           197  2018-01-01 01:59:32  2018-01-01 02:02:49              3211
# 4           932  2018-01-01 02:06:18  2018-01-01 02:21:50              3183
#
#   start station name  start station latitude  start station longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1   Marin Light Rail               40.714584               -74.042817
# 2            Sip Ave               40.730743               -74.063784
# 3         Newark Ave               40.721525               -74.046305
# 4     Exchange Place               40.716247               -74.033459
#
#    end station id       end station name  end station latitude  \
# ...

# %%
bikejc012018_df.shape
# Out:
# (12677, 16)

# %%
csv10_file = '201802_citibikejc_tripdata.csv'
bikejc022018_df = pd.read_csv(csv10_file)
bikejc022018_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           386  2018-02-01 00:30:21  2018-02-01 00:36:47              3205
# 1           724  2018-02-01 00:59:14  2018-02-01 01:11:19              3225
# 2           452  2018-02-01 03:50:25  2018-02-01 03:57:57              3280
# 3           358  2018-02-01 05:06:52  2018-02-01 05:12:51              3279
# 4           218  2018-02-01 05:14:48  2018-02-01 05:18:26              3267
#
#       start station name  start station latitude  start station longitude  \
# 0      JC Medical Center               40.716540               -74.049638
# 1  Baldwin at Montgomery               40.723659               -74.064194
# 2            Astor Place               40.719282               -74.071262
# 3            Dixon Mills               40.721630               -74.049968
# 4           Morris Canal               40.712419               -74.038526
#
# ...

# %%
bikejc022018_df.shape
# Out:
# (15104, 16)

# %%
csv11_file = '201801_citibikenyc_tripdata.csv'
bikenyc012018_df = pd.read_csv(csv11_file)
bikenyc012018_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           196  2018-01-01 00:01:51  2018-01-01 00:05:07               315
# 1           207  2018-01-01 00:02:44  2018-01-01 00:06:11              3224
# 2           613  2018-01-01 00:03:15  2018-01-01 00:13:28               386
# 3           375  2018-01-01 00:06:44  2018-01-01 00:12:59               466
# 4           402  2018-01-01 00:06:57  2018-01-01 00:13:40               438
#
#          start station name  start station latitude  start station longitude  \
# 0  South St & Gouverneur Ln               40.703554               -74.006702
# 1       W 13 St & Hudson St               40.739974               -74.005139
# 2      Centre St & Worth St               40.714948               -74.002345
# 3           W 25 St & 6 Ave               40.743954               -73.991449
# 4       St Marks Pl & 1 Ave               40.727791               -73.985649
#
# ...

# %%
bikenyc012018_df.shape
# Out:
# (718990, 16)

# %%
csv12_file = '201802_citibikenyc_tripdata.csv'
bikenyc022018_df = pd.read_csv(csv12_file)
bikenyc022018_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           509  2018-02-01 00:00:04  2018-02-01 00:08:34              3458
# 1           513  2018-02-01 00:00:15  2018-02-01 00:08:49               459
# 2           516  2018-02-01 00:00:16  2018-02-01 00:08:52               459
# 3           196  2018-02-01 00:00:16  2018-02-01 00:03:32              3318
# 4           491  2018-02-01 00:00:20  2018-02-01 00:08:31               499
#
#    start station name  start station latitude  start station longitude  \
# 0     W 55 St & 6 Ave               40.763094               -73.978350
# 1    W 20 St & 11 Ave               40.746745               -74.007756
# 2    W 20 St & 11 Ave               40.746745               -74.007756
# 3     2 Ave & E 96 St               40.783964               -73.947167
# 4  Broadway & W 60 St               40.769155               -73.981918
#
#    end station id         end station name  end station latitude  \
# ...

# %%
bikenyc022018_df.shape
# Out:
# (843104, 16)

# %%
frames = [bikenyc012018_df, bikejc012018_df]
bike012018_df = pd.concat(frames)

# %%
bike012018_df.shape
# Out:
# (731667, 16)

# %%
bike012018_df.to_csv('201801_citibike_tripdata.csv', index=False)

# %%
frames = [bikenyc022018_df, bikejc022018_df]
bike022018_df = pd.concat(frames)

# %%
bike022018_df.shape
# Out:
# (858208, 16)

# %%
bike022018_df.to_csv('201802_citibike_tripdata.csv', index=False)

# %%
frames = [bikenyc012018_df, bikejc012018_df, bikenyc022018_df, bikejc022018_df, bikenyc032018_df, bikejc032018_df]
bike2018_df = pd.concat(frames)

# %%
bike2018_df.to_csv('2018_citibike_tripdata.csv', index=False)
